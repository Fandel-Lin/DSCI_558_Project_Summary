# %%
from lxml import etree
import requests
from __future__ import print_function, division
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from uszipcode import SearchEngine
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import time
import random
import os
import csv

# %%
path= "chromedriver.exe"

# %%
driver= webdriver.Chrome(path)

driver.get('https://baseballsavant.mlb.com/leaderboard/custom?year=2022&type=pitcher&filter=&sort=4&sortDir=asc&min=q&selections=xba,xslg,xwoba,xobp,xiso,exit_velocity_avg,launch_angle_avg,barrel_batted_rate,&chart=false&x=xba&y=xba&r=no&chartType=beeswarm')

player_links=[]
player_names=[]
for i in range(1,200):
    try:
        player_links.append(driver.find_element(by=By.XPATH,value='/html/body/div[2]/div/div/table/tbody/tr[{}]/td[2]/span/a'.format(i)).get_attribute('href'))
        player_names.append(driver.find_element(by=By.XPATH,value='/html/body/div[2]/div/div/table/tbody/tr[{}]/td[2]/span/a'.format(i)).text.replace(' ','_').replace('.','').replace(',',''))
    except:
        pass

# %%
player_names
root_path = 'statistics/player_individual/'

for items in player_names:
    try:
        dirc = os.path.join(root_path, items)
        os.mkdir(dirc)
    except:
        pass

# %%
# loop
for l, j in zip(player_links, player_names):
    driver = webdriver.Chrome(path)
    ## table 1
    driver.get(l + '?stats=statcast-r-hitting-mlb')
    l = driver.current_url.split('?')[0]
    driver.get(l + '?stats=statcast-r-hitting-mlb')
    header = []
    try:
        for row in driver.find_element(by=By.XPATH,
                                       value='/html/body/div[2]/section/div/section/div[2]/div[1]/table/thead').find_elements_by_css_selector(
                'tr'):
            header = [d.text for d in row.find_elements_by_css_selector('th')]
        with open('statistics/player_individual/{}/Stats.csv'.format(j), 'w', newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
            wr.writerow(header)
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[2]/div[1]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    except:
        pass
    ## table 2
    header = []
    try:


        for i in range(1, 50):
            try:
                header.append(driver.find_element(by=By.XPATH,
                                                  value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[2]/table/thead/tr/th[{}]'.format(
                                                      i)).text)
            except:
                break
        with open('statistics/player_individual/{}/Statcast_batting_Statcast_Batting_Statistics.csv'.format(j), 'w',
                  newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
            wr.writerow(header)
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[2]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])


    except:
        pass
    ## table 3
    header = []
    try:

 
        for row in driver.find_element(by=By.XPATH,
                                       value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[6]/div[2]/div/table/thead').find_elements_by_css_selector(
                'tr'):
            header = [d.text for d in row.find_elements_by_css_selector('th')]

        with open('statistics/player_individual/{}/Statcast_batting_Pitch_Tracking.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
            wr.writerow(header)
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[6]/div[2]/div/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass
    ## table 4
    header = []
    try:


        for row in driver.find_element(by=By.XPATH,
                                       value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[8]/table/thead').find_elements_by_css_selector(
                'tr'):
            header = [d.text for d in row.find_elements_by_css_selector('th')]

        with open('statistics/player_individual/{}/Statcast_batting_Batted_Ball_Profile.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
            wr.writerow(header)
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[7]/section/div[1]/div[8]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 5
    header = []
    try:

 

        for row in driver.find_element(by=By.XPATH,
                                       value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[10]/table/thead').find_elements_by_css_selector(
                'tr'):
            header = [d.text for d in row.find_elements_by_css_selector('th')]

        with open('statistics/player_individual/{}/Statcast_batting_Run_Values_by_Pitch_Type.csv'.format(j), 'w',
                  newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
            wr.writerow(header)
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[10]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 6
    header = []
    try:


        with open('statistics/player_individual/{}/Statcast_batting_Swing_Take.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[12]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
                if header[0] == '':
                    header = [' '] + [' '] + [' '] + header
                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[12]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 7
    header = []
    try:

        with open('statistics/player_individual/{}/Statcast_batting_Plate_Discipline.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[14]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[14]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 8  
    header = []
    try:
        with open('statistics/player_individual/{}/Statcast_batting_Percentile_Rankings.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[16]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[16]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 9  
    header = []
    try:


        with open('statistics/player_individual/{}/Statcast_batting_Expected_Home_Runs.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[18]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[18]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass
        ## table 10
    header = []
    try:

   
        with open('statistics/player_individual/{}/Statcast_batting_Year_to_Year_Changes.csv'.format(j), 'w',
                  newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[22]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

        for row in driver.find_element(by=By.XPATH,
                                       value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[22]/table/tbody').find_elements_by_css_selector(
                'tr'):
            wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass
    ## table 11    
    header = []
    try:


        with open('statistics/player_individual/{}/Statcast_batting_Statcast_Shift_Statistics.csv'.format(j), 'w',
                  newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[24]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[7]/section/div[1]/div[24]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass
    ## table 12 
    header = []
    try:


        with open('statistics/player_individual/{}/Statcast_batting_Pitch_Tempo.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[27]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
                if header[0] == '':
                    header = [' '] + [' '] + [header[1]] + [' '] + [' '] + [' '] + [header[2]]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[1]/div[27]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass
    ## table 13 
    driver.get(l + '?stats=statcast-r-fielding-mlb')
    header = []
    try:

 
        with open('statistics/player_individual/{}/Statcast_fielding_Statcas_Outs_Above_Average.csv'.format(j), 'w',
                  newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/div[2]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/div[2]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 14
    header = []
    try:


        with open(
                'statistics/player_individual/{}/Statcast_fielding_Statcast_Detailed_Outfield_Outs_Above_Average.csv'.format(
                        j), 'w', newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/div[4]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/div[4]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 15
    header = []
    try:


        with open('statistics/player_individual/{}/Statcast_fielding_Statcast_Arm_Strength.csv'.format(j), 'w',
                  newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/div[7]/div[2]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                if len(header) == 7:
                    header = [' '] + [' '] + [' '] + [' '] + [header[0]] + [' '] + [header[1]] + [' '] + [header[2]] + [
                        ' '] + [header[3]] + [' '] + [header[4]] + [' '] + [header[5]] + [' '] + [header[6]]
                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/div[7]/div[2]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

        ## table 16       

    header = []
    try:

   
        with open('statistics/player_individual/{}/Statcast_fielding_Statcast_Fielder_Positioning.csv'.format(j), 'w',
                  newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

        ## table 17
    header = []
    try:

   
        with open('statistics/player_individual/{}/Statcast_fielding_Statcast_Outfielder_Jump.csv'.format(j), 'w',
                  newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/div[11]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
                if header[0] == '':
                    header = [' '] + [header[1]] + [' '] + [' '] + [' '] + [header[2]] + [' '] + [' '] + [header[3]]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[2]/div[11]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
   
    except:
        pass

    ## table 18      
    driver.get(l + '?stats=statcast-r-running-mlb')
    header = []
    try:

 
        with open('statistics/player_individual/{}/Statcast_running_Statcast_Running_Statistics.csv'.format(j), 'w',
                  newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[3]/div[2]/div/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[3]/div[2]/div/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
 
    except:
        pass

        ## table 19     
    header = []
    try:

 
        with open('statistics/player_individual/{}/Statcast_running_5ft_Running_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[7]/section/div[3]/div[6]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[7]/section/div[3]/div[6]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 20   
    driver.get(l + '?stats=career-r-zones-mlb')
    header = []
    try:

 
        with open('statistics/player_individual/{}/Standard_MLB_Batting_Standard_MLB_Batting_Statistics.csv'.format(j),
                  'w', newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[1]/div[1]/div[1]/table[1]/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[1]/div[1]/div[1]/table[1]/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
  
    except:
        pass

    ## table 21
    header = []
    try:

 
        with open('statistics/player_individual/{}/Standard_MLB_Batting_Advanced_MLB_Batting_Statistics.csv'.format(j),
                  'w', newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[1]/div[1]/div[1]/table[2]/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[1]/div[1]/div[1]/table[2]/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 22 
    driver.get(l + '?stats=career-r-fielding-mlb')
    header = []
    try:


        with open(
                'statistics/player_individual/{}/Standard_MLB_Fielding_Standard_MLB_Fielding_Statistics.csv'.format(j),
                'w', newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[1]/div[3]/div[1]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[1]/div[3]/div[1]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 23 
    header = []
    try:


        with open(
                'statistics/player_individual/{}/Standard_Minors_Batting_Standard_Minor_league_Batting_Statistics.csv'.format(
                        j), 'w', newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[2]/div[1]/div[1]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]

                wr.writerow(header)

            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[2]/div[1]/div[1]/table[1]/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])

    except:
        pass

    ## table 24        
    driver.get(l + '?stats=career-r-fielding-milb')
    header = []
    try:
    
    
        with open(
                'statistics/player_individual/{}/Standard_Minors_Fielding_Standard_Minor_league_Fielding_Statistics.csv'.format(
                        j), 'w', newline='', encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[2]/div[3]/div[1]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[4]/div[2]/div[3]/div[1]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    except:
        pass
    
    ## table 25
    driver.get(l + '?stats=splits-r-hitting-mlb&season')
    
    header = []
    try:
    
    
        with open('statistics/player_individual/{}/Splits_MLB_Platoon_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[5]/div[1]/div[1]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[5]/div[1]/div[1]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    
    except:
        pass
    
    header = []
    try:
    
    
        with open('statistics/player_individual/{}/Splits_MLB_Monthly_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[1]/div[2]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[1]/div[2]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    except:
        pass
    
    header = []
    try:
    
    
        with open('statistics/player_individual/{}/Splits_MLB_Batting_Order_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[1]/div[3]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[1]/div[3]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    except:
        pass
    
    header = []
    try:
    
    
        with open('statistics/player_individual/{}/Splits_MLB_Base_Runner_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[1]/div[4]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[1]/div[4]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    
    except:
        pass
    
    header = []
    try:
    
    
        with open('statistics/player_individual/{}/Splits_MLB_Game_Type_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[1]/div[5]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[1]/div[5]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    
    except:
        pass
    
    header = []
    try:
    
    
        with open('statistics/player_individual/{}/Splits_MLB_Outs_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[1]/div[6]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[1]/div[6]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    
    except:
        pass
    
    header = []
    try:
    
    
        with open('statistics/player_individual/{}/Splits_MLB_Inning_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[1]/div[7]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[1]/div[7]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    except:
        pass
    
        ## table 26
    driver.get(l + '?stats=splits-r-hitting-milb&season')
    
    header = []
    try:
    
    
        with open('statistics/player_individual/{}/Splits_Minors_Platoon_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[5]/div[2]/div[1]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='/html/body/div[2]/section/div/section/div[5]/div[2]/div[1]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    except:
        pass
    
    header = []
    try:
    
    
        with open('statistics/player_individual/{}/Splits_Minors_Monthly_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[2]/div[2]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[2]/div[2]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    except:
        pass
    
    header = []
    try:
    
        with open('statistics/player_individual/{}/Splits_Minors_Batting_Order_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[2]/div[3]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[2]/div[3]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    except:
        pass
    
    header = []
    try:
    
        with open('statistics/player_individual/{}/Splits_Minors_Base_Runner_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[2]/div[4]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[2]/div[4]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    except:
        pass
    
    header = []
    try:
    
        with open('statistics/player_individual/{}/Splits_Minors_Game_Type_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[2]/div[5]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[2]/div[5]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    
    except:
        pass
    
    header = []
    try:
    
        with open('statistics/player_individual/{}/Splits_Minors_Outs_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[2]/div[6]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[2]/div[6]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    
    except:
        pass
    
    header = []
    try:
    
        with open('statistics/player_individual/{}/Splits_Minors_Inning_Splits.csv'.format(j), 'w', newline='',
                  encoding='utf-8') as csvfile:
            wr = csv.writer(csvfile)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='//html/body/div[2]/section/div/section/div[5]/div[2]/div[7]/table/thead').find_elements_by_css_selector(
                    'tr'):
                header = [d.text for d in row.find_elements_by_css_selector('th')]
    
                wr.writerow(header)
    
            for row in driver.find_element(by=By.XPATH,
                                           value='html/body/div[2]/section/div/section/div[5]/div[2]/div[7]/table/tbody').find_elements_by_css_selector(
                    'tr'):
                wr.writerow([d.text for d in row.find_elements_by_css_selector('td')])
    
    except:
        pass
    
    driver.quit()
    time.sleep(10)
